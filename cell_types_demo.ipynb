# %% [markdown]
# # Understanding Code vs Markdown Cells

# %% [markdown]
# ## Purpose
# This notebook demonstrates the difference between Code cells and Markdown cells.

# %%
print("This is a code cell running Python")
# Out:
# This is a code cell running Python

# %% [markdown]
# ### Explanation
# Code cells execute Python code and produce output.

# %%
x = 5
y = 10
print("Sum:", x + y)
# Out:
# Sum: 15
