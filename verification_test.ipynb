# %% [markdown]
# # Data Science Environment Verification
#
# This notebook verifies that the Data Science environment is properly configured for the TourTide project.

# %%
# Python Version Check
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# %%
# Basic Python Functionality Test
import math
import json
import datetime

# Test basic calculations
result = sum(range(100))
print(f"Basic calculation test: sum(range(100)) = {result}")

# Test math operations
print(f"Math test: sqrt(16) = {math.sqrt(16)}")

# Test datetime
current_time = datetime.datetime.now()
print(f"Current time: {current_time}")

# %%
# Data Science Libraries Check
try:
    import numpy as np
    print(f"✓ NumPy version: {np.__version__}")
except ImportError:
    print("✗ NumPy not installed")

try:
    import pandas as pd
    print(f"✓ Pandas version: {pd.__version__}")
except ImportError:
    print("✗ Pandas not installed")

try:
    import matplotlib
    print(f"✓ Matplotlib version: {matplotlib.__version__}")
except ImportError:
    print("✗ Matplotlib not installed")

# %%
# Environment Summary
print("=" * 50)
print("DATA SCIENCE ENVIRONMENT VERIFICATION COMPLETE")
print("=" * 50)
print(f"✓ Python: {sys.version.split()[0]}")
print("✓ Jupyter Notebook: Running successfully")
print("✓ Basic Python functionality: Working")
print("✓ Environment ready for TourTide development")
print("=" * 50)
